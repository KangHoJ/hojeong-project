# %% [markdown]
# ### 연습문제

# %%
nfl = pd.read_csv('datas/nfl.csv',parse_dates=['Birthday'],index_col='Name')
nfl # 1
# Out:
#                                     Team Position   Birthday   Salary
# Name
# Tremon Smith         Philadelphia Eagles       RB 1996-07-20   570000
# Shawn Williams        Cincinnati Bengals       SS 1991-05-13  3500000
# Adam Butler         New England Patriots       DT 1994-04-12   645000
# Derek Wolfe               Denver Broncos       DE 1990-02-24  8000000
# Jake Ryan           Jacksonville Jaguars      OLB 1992-02-27  1000000
# ...                                  ...      ...        ...      ...
# Bashaud Breeland      Kansas City Chiefs       CB 1992-01-30   805000
# Craig James          Philadelphia Eagles       CB 1996-04-29   570000
# Jonotthan Harrison         New York Jets        C 1991-08-25  1500000
# Chuma Edoga                New York Jets       OT 1997-05-25   495000
# Tajae Sharpe            Tennessee Titans       WR 1994-12-23  2025000
#
# [1655 rows x 4 columns]

# %%
nfl['Team'].value_counts() #2
# Out:
# New York Jets           58
# Kansas City Chiefs      56
# Washington Redskins     56
# New Orleans Saints      55
# San Francisco 49Ers     55
# Denver Broncos          54
# Minnesota Vikings       54
# Los Angeles Chargers    54
# Seattle Seahawks        53
# Dallas Cowboys          53
# Buffalo Bills           53
# Atlanta Falcons         53
# Detroit Lions           53
# Chicago Bears           53
# Los Angeles Rams        52
# New York Giants         52
# Philadelphia Eagles     52
# Houston Texans          52
# Arizona Cardinals       51
# Cincinnati Bengals      51
# Green Bay Packers       51
# Oakland Raiders         51
# Jacksonville Jaguars    50
# Cleveland Browns        49
# Miami Dolphins          49
# Indianapolis Colts      49
# Carolina Panthers       49
# New England Patriots    49
# Baltimore Ravens        48
# Pittsburgh Steelers     47
# Tampa Bay Buccaneers    47
# Tennessee Titans        46
# Name: Team, dtype: int64

# %%
nba.nlargest(5,columns=['Salary']) # 3
# Out:
#                                     Team Position   Birthday    Salary
# Name
# Stephen Curry      Golden State Warriors       PG 1988-03-14  40231758
# Chris Paul         Oklahoma City Thunder       PG 1985-05-06  38506482
# Russell Westbrook        Houston Rockets       PG 1988-11-12  38506482
# John Wall             Washington Wizards       PG 1990-09-06  38199000
# James Harden             Houston Rockets       PG 1989-08-26  38199000

# %%
nfl.sort_values(by=['Team','Salary'],ascending=[True,False]) #4
# Out:
#                                    Team Position   Birthday    Salary
# Name
# Chandler Jones        Arizona Cardinals      OLB 1990-02-27  16500000
# Patrick Peterson      Arizona Cardinals       CB 1990-07-11  11000000
# Larry Fitzgerald      Arizona Cardinals       WR 1983-08-31  11000000
# David Johnson         Arizona Cardinals       RB 1991-12-16   5700000
# Justin Pugh           Arizona Cardinals        G 1990-08-15   5000000
# ...                                 ...      ...        ...       ...
# Ross Pierschbacher  Washington Redskins        C 1995-05-05    495000
# Kelvin Harmon       Washington Redskins       WR 1996-12-15    495000
# Wes Martin          Washington Redskins        G 1996-05-09    495000
# Jimmy Moreland      Washington Redskins       CB 1995-08-26    495000
# Jeremy Reaves       Washington Redskins       SS 1996-08-29    495000
#
# [1655 rows x 4 columns]

# %% [markdown]
# ### 연습문제

# %%
titanic['category1']=titanic.apply(lambda r:r['sex'] if r.age >=20 else 'child',axis=1)
titanic # 성별이 20살이 넘으면 성별 그대로 사용 , 20살보다 적으면 성별에 상관없이 child
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %% [markdown]
# ### 연습문제

# %%
titanic[titanic['age'].isna()] # NAN값이 어디있는지 찾아줌
titanic[titanic['age'].isna()].index # NAN값 있는 위치 index 찾아줌
titanic.fillna({'age':titanic['age'].mean()},inplace=True) # NAN값 평균 대체

# %% [markdown]
# - astype() 메서드

# %%
df.astype({'col1':'int32'}).dtype

# %%
employee = pd.read_csv('datas/employees.csv',parse_dates=['Start Date'])

# %% [markdown]
# ### 연습문제

# %%
employee['Salary'].fillna(0)
# employee['Salary'] = employee['Salary'].astype(int)
# Out:
# 0            0.0
# 1        61933.0
# 2       130590.0
# 3       138705.0
# 4       101004.0
#           ...
# 996      42392.0
# 997      96914.0
# 998      60500.0
# 999     129949.0
# 1000         0.0
# Name: Salary, Length: 1001, dtype: float64

# %% [markdown]
# ### 연습문제

# %%
employee.nunique() # 고유값 개수를 먼저 확인 (gender , team이 적음)
employee['Gender'].value_counts()
employee['Team'].value_counts()
employee['Gender'] = employee['Gender'].astype('category')
employee['Team'] = employee['Team'].astype('category')
employee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First Name  933 non-null    object
#  1   Gender      854 non-null    category
#  2   Start Date  999 non-null    datetime64[ns]
#  3   Salary      999 non-null    float64
#  4   Mgmt        933 non-null    object
#  5   Team        957 non-null    category
# dtypes: category(2), datetime64[ns](1), float64(1), object(2)
# memory usage: 33.9+ KB

# %% [markdown]
# ### 연습문제

# %%
titanic['category2'] = titanic['sex']+titanic['age'].astype('str')
titanic
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town alive  alone adult/child  \
# ...

# %% [markdown]
# ### 연습문제

# %%
bins=[1,20,30,50,70,100]
labels = [ '미성년자', '쳥년','장년','중년','노년']
titanic_age =pd.cut(titanic['age'],bins,labels=labels).value_counts() # age중 범주에따라 다르게 분배(몇명씩인지)
titanic_age_rate = titanic_age/titanic_age.sum()
titanic_age_rate

df_titanic_age = pd.DataFrame({'연령층':titanic_age,'연령 비율':titanic_age_rate},index=labels)
df_titanic_age.loc['합계'] = df_titanic_age.sum(axis=0)
df_titanic_age
# Out:
#         연령층     연령 비율
# 미성년자  165.0  0.188141
# 쳥년    407.0  0.464082
# 장년    241.0  0.274800
# 중년     59.0  0.067275
# 노년      5.0  0.005701
# 합계    877.0  1.000000

# %%
titanic['연령층'] = pd.cut(titanic['age'],bins,labels=labels)
titanic['성별구분'] = titanic.apply(lambda k: '남자' if k.sex == 'male' else '여자', axis =1)
titanic['category3'] = titanic.apply(lambda r:r['연령층'] + r['성별구분'] if r.age >=20 else '미성년자',axis=1)
titanic
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  ...  deck  embark_town alive  alone  adult/child  \
# ...
