# %% [markdown]
# ## matplot 시각화

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
plt.title('plot')
plt.plot([1,4,9,16]) # y축으로 쓰임 
plt.show()

# %%
plt.title('x ticks')
plt.plot([10,20,30,40],[1,4,9,16]) # x,y축으로 쓰임 
plt.show()

# %%
# %pwd # 현재 경로
# Out:
# 'C:\\Users\\User\\Desktop\\boot camp'

# %%
# %cd C:\\Users\\User\\Desktop\\boot camp # 경로 변경
# Out:
# C:\Users\User\Desktop\boot camp

# %% [markdown]
# ## 외부 font 불러오기

# %%
import matplotlib as mpl
# Add every font at the specified location
font_dir = ['./fonts']
for font in mpl.font_manager.findSystemFonts(fontpaths=font_dir):
    print(mpl.font_manager.FontProperties(fname=font).get_name())
    mpl.font_manager.fontManager.addfont(font)
# Out:
# Nanum Pen Script OTF
# NanumSquareOTF
# NanumGothicOTF
# NanumMyeongjoOTF Eco
# NanumSquareOTF_ac
# NanumBarunGothic
# NanumGothic
# NanumGothic Eco
# NanumBarunGothicOTF
# NanumMyeongjo Eco
# NanumMyeongjoOTF
# NanumBarunpen
# NanumSquareOTF
# D2Coding ligature
# NanumSquare Neo OTF Heavy
# Noto Sans KR
# NanumSquare_ac
# NanumSquare_ac
# NanumSquare Neo Bold
# NanumSquare Neo OTF ExtraBold
# NanumGothicOTF Eco
# Noto Sans KR
# NanumSquareRoundOTF
# NanumSquareOTF_ac
# NanumBarunpenOTF
# NanumSquareRoundOTF
# NanumMyeongjoOTF Eco
# NanumGothicOTF
# NanumBarunGothicOTF YetHangul
# NanumMyeongjoOTF
# NanumSquare_ac
# NanumBarunpen
# Noto Sans KR
# NanumBarunGothic YetHangul
# NanumSquare
# D2Coding ligature
# NanumBarunGothicOTF
# NanumMyeongjo
# Nanum Brush Script OTF
# NanumSquare Neo ExtraBold
# NanumMyeongjo YetHangul
# NanumMyeongjoOTF YetHangul
# NanumSquareOTF_ac
# NanumBarunGothic
# NanumSquare Neo Light
# NanumBarunpenOTF
# NanumGothic
# NanumMyeongjo
# NanumBarunGothicOTF
# ...

# %%
# Set font family globally
mpl.rcParams['font.family'] = 'Noto Sans KR'
print(mpl.rcParams['font.family'])
# Out:
# ['Noto Sans KR']

# %%
plt.title('한글')
plt.plot(range(1,5))
plt.show()

# %%
global_font = {'family' : 'NanumGothic','size':12,'weight':'bold'}
mpl.rc('font',**global_font)

# %%
plt.title('x ticks')
plt.plot([10,20,30,40],[1,4,9,16]) # x,y축으로 쓰임 
plt.xlabel('가나')
plt.ylabel('b')
plt.show()

# %%
title_font = {'family' : 'NamumMyeongjo','size':24,'color':'black'}
xlabel_font = {'family' : 'NanumBarupen','size':18,'weight' : 'bold','color':'darkred'}
ylabel_font = {'family' : 'NanumBarunGothic','size':12,'weight' : 'light','color':'blue'}
plt.plot([10,20,30,40],[1,4,9,16])
plt.title('한글제목',fontdict=title_font)
plt.title('엑스 축',fontdict=xlabel_font)
plt.title('와이 축',fontdict=ylabel_font)
plt.show()

# %%
mpl.rc('axes',unicode_minus=False) # ASCII 문자 설정

# %%
plt.title("'rs--' 스타일의 plot")
plt.plot([10,20,30,40],[1,4,9,16],'b*--') #rp 스타일
plt.show()
# 스타일을 설정할때는 색상 , 마커 , 선종류 순서 b*-  ->검정색 -> *모양 -> solod line

# %%
plt.plot([10,20,30,40],[1,4,9,6],c='b',lw=5,ls='--',marker='o',ms=15,mec='g',mew=5,mfc='r')
plt.title('스타일 적용 예') 
#b(선 색상),ㅣw(선 굵기),marker(모양),ms(모양 사이즈),mec(선색상),mew(마커선굵기),mfc(마커내부색상)
plt.show()

# %%
plt.title('x축 y축의 범위 설정')
plt.plot([10,20,30,40],[1,4,9,6],c='b',lw=5,ls='--',marker='o',ms=15,mec='g',mew=5,mfc='r')
plt.xlim(0,50) # x축 범위 설정
plt.ylim(-10,30) # y축 범위 설정 
plt.show()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import numpy as np
X = np.linspace(-np.pi,np.pi,256)
C = np.cos(X)
plt.title('x축과 y축의 tick label 설정')
plt.plot(X,C)
plt.xticks([-np.pi , -np.pi/2,0,np.pi/2,np.pi])
plt.yticks([-1,0,1])
plt.show()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import numpy as np
X = np.linspace(-np.pi,np.pi,256)
C = np.cos(X)
plt.title('Tex, 문자열로 tick label 정의')
plt.plot(X,C)
plt.xticks([-np.pi , -np.pi/2,0,np.pi/2,np.pi],
          [r'$-\pi$',r'$-\pi/2$',r'$0$',r'$+\pi/2$',r'$+\pi$'])
plt.yticks([-1,0,1],['Low','Zero','High'])
plt.show()

# %% [markdown]
# ## 여려개의 선 그리기

# %%
t = np.arange(0.,5.,0.2)
plt.title('라인 플롯에서 여러개의 선 그리기')
plt.plot(t,t,'r--',t,0.5 * t**2, 'bs:',t,0.2*t**3,'g^-')

# %%
plt.title('복수의 plot 명령을 한 그림에서 표현')
style1 = {'c':'b','lw':5,'ls':'--','marker':'o','ms':15,'mec':'g','mew':5,'mfc':'r'}
style2 = {'c':'k','lw':3,'ls':':','marker':'s','ms':10,'mec':'m','mew':5,'mfc':'c'}

plt.plot([1,4,9,16],**style1)
plt.plot([9,16,4,1],**style2)
plt.show()

# %%
X = np.linspace(-np.pi,np.pi,256)
C,S = np.cos(X) , np.sin(X)
plt.title('legend를 표시한 플롯')
plt.plot(X,C,ls='--',label='cosine')
plt.plot(X,S,ls=':',label='sine')
plt.legend(loc=2)
plt.show()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
X = np.linspace(-np.pi,np.pi,256)
C,S = np.cos(X) , np.sin(X)
plt.plot(X,C,label='cosine')
plt.xlabel('time') # x축범례
plt.ylabel('amplitude') # y축범례
plt.title('Cosine Plot')
plt.show()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## 연습문제

# %%
import numpy as np

plt.title("섭씨 온도와 화씨 온도")
plt.xlabel('화씨온도') # x축범례
plt.ylabel('섭씨온도') # y축범례
x = np.arange(32,100)
y = (x-32) * 5/9
plt.plot(x,y,'r-.')

# %% [markdown]
# ## figure

# %%
fig , ax = plt.subplots()
ax.plot([1,2,3,4],[1,4,2,3])

# %%
fig = plt.figure()
# fig , ax = plt.subplots()
fig , ax = plt.subplots(2,2)

# %%
np.random.seed(0)
fl = plt.figure(figsize=(10,2)) # 인치기준 10,2
plt.title('firgure size : (10,2)')
plt.plot(np.random.randn(100)) # 난수 100개
plt.show()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
f1 = plt.figure()
plt.title('현재의 Figure 객체')
plt.plot([1,2,3,4],'ro:')

print(f1,id(f1))
# Out:
# Figure(432x288) 3015746540688

# %% [markdown]
# ## Axes

# %%
ax1 = plt.subplot(2,1,1)
ax2 = plt.subplot(2,1,2)

# %%
x1 = np.linspace(0.0,5.0)
x2 = np.linspace(0.0,2.0)
y1 = np.cos(2*np.pi*x1) * np.exp(-x1)
y2 = np.cos(2*np.pi*x2)

plt.subplot(2,1,1) # 위에 그린다
plt.plot(x1,y1,'yo-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')

plt.subplot(2,1,2) # 아래 그린다
plt.plot(x2,y2,'r.-')
plt.xlabel('time(s)')
plt.ylabel('Undamped')

plt.tight_layout() # 그래프간 간격을 조금 띄운다
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_18140\2078639500.py:16: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   plt.tight_layout() # 그래프간 간격을 조금 띄운다
# C:\Users\User\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
np.random.seed(0)

plt.subplot(221) # (2,2,1) -> (221)
plt.plot(np.random.rand(5))
plt.title('axes 1')

plt.subplot(222) # (2,2,2) -> (222)
plt.plot(np.random.rand(5))
plt.title('axes 2')

plt.subplot(223) # (2,2,3) -> (223)
plt.plot(np.random.rand(5))
plt.title('axes 3')

plt.subplot(224) # (2,2,4) -> (224)
plt.plot(np.random.rand(5))
plt.title('axes 4')

plt.tight_layout()
plt.show()

# %%
# 방법 2
fig , axes = plt.subplots(2,2)

np.random.seed(0)
axes[0,0].plot(np.random.rand(5))
axes[0,0].set_title('axes 1')
axes[0,1].plot(np.random.rand(5))
axes[0,1].set_title('axes 2')
axes[1,0].plot(np.random.rand(5))
axes[1,0].set_title('axes 3')
axes[1,1].plot(np.random.rand(5))
axes[1,1].set_title('axes 4')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Axis

# %%
fig , ax0 = plt.subplots()
ax1 = ax0.twinx()
ax0.set_title('2개의 y축 한 figuer에서 사용하기') # 제목

ax0.plot([10,5,2,9,7],'r-') # 빨간 그래프
ax0.set_ylabel('y0')
ax0.grid(False)
ax1.plot([100,200,220,180,120], 'g:')
ax1.set_ylabel('y1')
ax1.grid(False)

ax0.set_xlabel('공유되는 x축') # x축 범례
plt.show()
