# %%
# %pwd
# Out:
# 'C:\\Users\\User\\Desktop\\boot camp\\파이썬 기초\\3.13 matplot 시각화'

# %%
# %cd C:\\Users\\User\\Desktop\\boot camp
# Out:
# C:\Users\User\Desktop\boot camp

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# Add every font at the specified location
font_dir = ['./fonts']
for font in mpl.font_manager.findSystemFonts(fontpaths=font_dir):
    print(mpl.font_manager.FontProperties(fname=font).get_name())
    mpl.font_manager.fontManager.addfont(font)
# Out:
# NanumMyeongjoOTF
# NanumSquareRound
# NanumSquare Neo OTF ExtraBold
# NanumSquareRound
# NanumSquare_ac
# NanumSquare_ac
# NanumMyeongjo
# NanumMyeongjo Eco
# NanumSquare Neo Bold
# NanumSquare
# NanumBarunGothic YetHangul
# NanumBarunpenOTF
# NanumSquare
# NanumSquare Neo OTF Regular
# Nanum Brush Script
# NanumMyeongjoOTF
# NanumSquare_ac
# NanumMyeongjoOTF Eco
# Nanum Brush Script OTF
# NanumSquare Neo OTF Heavy
# NanumMyeongjoOTF Eco
# NanumBarunGothicOTF
# NanumSquareRoundOTF
# NanumMyeongjoOTF YetHangul
# NanumSquareOTF
# NanumSquareRoundOTF
# NanumBarunGothicOTF
# NanumBarunGothicOTF
# D2Coding ligature
# D2Coding ligature
# Noto Sans KR
# NanumGothicOTF
# NanumBarunGothic
# NanumBarunGothic
# NanumSquareOTF
# NanumSquare
# NanumBarunGothic
# NanumGothicOTF Eco
# NanumMyeongjoOTF
# NanumGothic Eco
# NanumMyeongjo Eco
# NanumGothic
# Noto Sans KR
# NanumSquare
# NanumBarunGothicOTF
# NanumSquare Neo OTF Light
# NanumMyeongjoOTF Eco
# NanumMyeongjo
# NanumSquare Neo Regular
# ...

# %%
# Set font family globally
mpl.rcParams['font.family'] = 'Noto Sans KR'
print(mpl.rcParams['font.family'])
# Out:
# ['Noto Sans KR']

# %%
import numpy as np
np.random.seed(0)
x = np.random.randn(1000)
plt.title('Histogram')
plt.hist(x)
plt.show()

# %%
np.random.seed(0)
x = np.random.normal(0,1,100)
Y = np.random.normal(0,1,100)
plt.title('Scatter plot')
plt.scatter(x,Y)
plt.show()

# %%
N = 30
np.random.seed(0)
x = np.random.rand(N)
y1 = np.random.rand(N)
y2 = np.random.rand(N)
y3 = np.pi * (15 * np.random.rand(N))**2
plt.title('Bubble chart')
plt.scatter(x,y1,c=y2,s=y3) # 크기는 s 색깔은 c 
plt.show()

# %% [markdown]
# ## inshow

# %%
from sklearn.datasets import load_digits
digits = load_digits()
X = digits.images[0]
X
# Out:
# array([[ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.],
#        [ 0.,  0., 13., 15., 10., 15.,  5.,  0.],
#        [ 0.,  3., 15.,  2.,  0., 11.,  8.,  0.],
#        [ 0.,  4., 12.,  0.,  0.,  8.,  8.,  0.],
#        [ 0.,  5.,  8.,  0.,  0.,  9.,  8.,  0.],
#        [ 0.,  4., 11.,  0.,  1., 12.,  7.,  0.],
#        [ 0.,  2., 14.,  5., 10., 12.,  0.,  0.],
#        [ 0.,  0.,  6., 13., 10.,  0.,  0.,  0.]])

# %%
plt.title('mnist digits; 0')
plt.imshow(X,interpolation='nearest',cmap=plt.cm.bone_r)
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.subplots_adjust(left=0.35,right=0.65,bottom=0.35,top=0.65)
plt.show()

# %%
dir(plt.cm)[:10] # 사용할 수 있는 color 10개만 조회
# Out:
# ['Accent',
#  'Accent_r',
#  'Blues',
#  'Blues_r',
#  'BrBG',
#  'BrBG_r',
#  'BuGn',
#  'BuGn_r',
#  'BuPu',
#  'BuPu_r']

# %%
methods = {
    None, 'none', 'nearest', 'bilinear', 'bicubic', 'spline16', 'spline36',
    'hanning', 'hamming', 'hermite', 'kaiser', 'quadric', 'catrom', 'gaussian',
    'bessel', 'mitchell', 'sinc', 'lanczos'
}
fig, axes = plt.subplots(3, 6, figsize = (12, 6),
                         subplot_kw = {'xticks' : [], 'yticks' : []})
for ax, interp_method in zip(axes.flat, methods):
    ax.imshow(X, cmap = plt.cm.bone_r, interpolation = interp_method)
    ax.set_title(interp_method)
    
plt.show()

# %% [markdown]
# ## 컨투어 플롯

# %%
def f(x,y):
    return (1-x/ 2+x ** 5 + y ** 3) * np.exp(-x **2 -y **2)

n = 256
x = np.linspace(-3,3,n)
y = np.linspace(-3,3,n)
XX,YY = np.meshgrid(x,y)
ZZ = f(XX,YY)

plt.title('contour plots')
plt.contourf(XX,YY,ZZ,alpha=.75,cmap='jet')
plt.contour(XX,YY,ZZ,colors='black')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axee3D
X = np.arange(-4,4,0.25)
Y = np.arange(-4,4,0,25)
XX , YY = np.meshgrid(X,Y)
RR = np.sqrt(XX**2 + YY**2)
ZZ = np.sin(RR)

fit = plt.figure()
ax = Axes3D(fig)
ax.set_title('3D surface plot')
ax.plot_surface(XX,YY,ZZ,retride=1,cstride=1,cmap='hot')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [24], in <cell line: 1>()
# ----> 1 from mpl_toolkits.mplot3d import Axee3D
#       2 X = np.arange(-4,4,0.25)
#       3 Y = np.arange(-4,4,0,25)
#
# ImportError: cannot import name 'Axee3D' from 'mpl_toolkits.mplot3d' (C:\Users\User\anaconda3\lib\site-packages\mpl_toolkits\mplot3d\__init__.py)
