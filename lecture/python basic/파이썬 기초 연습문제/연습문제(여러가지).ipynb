# %% [markdown]
# ### 연습문제

# %%
nfl = pd.read_csv('datas/nfl.csv',parse_dates=['Birthday'],index_col=['Name'])
nfl = nfl.reset_index()
nfl2 = nfl.set_index('Team')
nfl3 = nfl2.sort_values('Birthday')
nfl3.loc['New York Jets'].head(1)
# Out:
#                      Name Position   Birthday   Salary
# Team
# New York Jets  Ryan Kalil        C 1985-03-29  2400000

# %%
## 강사님 풀이
nfl.reset_index().set_index('Team').loc['New York Jets'].nsmallest(1,'Birthday')
# Out:
#                      Name Position   Birthday   Salary
# Team
# New York Jets  Ryan Kalil        C 1985-03-29  2400000

# %%
data = {
    '이름' : ['일식','야식','삼식','사식','오식'],
    '국어' : [60,70,90,80,100],
    '영어' : [70,86,82,88,100],
    '수학' : [65,82,85,90,100]
}
data = pd.DataFrame(data)
data2 = data.set_index('이름')
data2.reset_index()
# Out:
#    이름   국어   영어   수학
# 0  일식   60   70   65
# 1  야식   70   86   82
# 2  삼식   90   82   85
# 3  사식   80   88   90
# 4  오식  100  100  100

# %% [markdown]
# ### 연습문제

# %%
import seaborn as sns
titanic=sns.load_dataset('titanic')

# %%
def change_boolean(value):
    if value == 'yes':
        return True
    else:
        return False

titanic['alive'] = titanic['alive'].apply(change_boolean)

# %%
titanic = titanic.dropna(subset = ['age'])
titanic['adult_female column'] = (titanic['age'] >=20) & (titanic['sex'] == 'female')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town  alive  alone  adult_female column
# 0      man        True  NaN  Southampton  False  False                False
# 1    woman       False    C    Cherbourg  False  False                 True
# 2    woman       False  NaN  Southampton  False   True                 True
# 3    woman       False    C  Southampton  False  False                 True
# 4      man        True  NaN  Southampton  False   True                False
# ..     ...         ...  ...          ...    ...    ...                  ...
# 885  woman       False  NaN   Queenstown  False  False                 True
# 886    man        True  NaN  Southampton  False   True                False
# 887  woman       False    B  Southampton  False   True                False
# 889    man        True    C    Cherbourg  False   True                False
# 890    man        True  NaN   Queenstown  False   True                False
#
# [714 rows x 16 columns]
