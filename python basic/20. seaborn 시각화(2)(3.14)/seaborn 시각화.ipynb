C:\\Windows\\Fonts\\DUBAI-MEDIUM.TTF', 'C:\\Windows\\Fonts\\MTCORSVA.TTF', 'C:\\Windows\\Fonts\\trebucbd.ttf', 'C:\\Windows\\Fonts\\framd.ttf', 'C:\\Windows\\Fonts\\WINGDNG3.TTF', 'C:\\Windows\\Fonts\\HANBatangExtB.ttf', 'C:\\Windows\\Fonts\\HANBatang.ttf', 'C:\\Windows\\Fonts\\couri.ttf', 'C:\\Windows\\Fonts\\Candarai.ttf', 'C:\\Windows\\Fonts\\msjhbd.ttc', 'C:\\Windows\\Fonts\\consolab.ttf', 'C:\\Windows\\Fonts\\H2GTRE.TTF', 'C:\\Windows\\Fonts\\msjhl.t ...

# %%
# %pwd
# Out:
# 'C:\\Users\\User\\Desktop\\boot camp\\파이썬 기초\\3.14 seaborn 시각화(2)'

# %%
# %cd C:\\Users\\User\\Desktop\\boot camp
# Out:
# C:\Users\User\Desktop\boot camp

# %%
import matplotlib as mpl
# Add every font at the specified location
font_dir = ['./fonts']
for font in mpl.font_manager.findSystemFonts(fontpaths=font_dir):
 print(mpl.font_manager.FontProperties(fname=font).get_name())
 mpl.font_manager.fontManager.addfont(font)
# Out:
# NanumMyeongjo Eco
# NanumSquare_ac
# NanumBarunpen
# NanumSquareRound
# NanumBarunpenOTF
# NanumSquare_ac
# NanumBarunpenOTF
# NanumBarunGothicOTF
# NanumBarunGothic
# Nanum Pen Script
# NanumSquareOTF
# Nanum Brush Script
# NanumSquare_ac
# NanumGothic
# NanumSquare Neo OTF Heavy
# NanumSquare
# NanumMyeongjoOTF Eco
# NanumGothic Eco
# NanumSquareRoundOTF
# Nanum Brush Script OTF
# NanumSquareOTF_ac
# NanumGothicOTF
# NanumSquare Neo OTF Regular
# NanumSquare
# NanumSquareRoundOTF
# NanumSquare
# D2Coding ligature
# NanumSquare Neo Heavy
# NanumSquare
# NanumBarunpen
# NanumSquare Neo Light
# NanumBarunGothicOTF
# NanumMyeongjo Eco
# NanumSquare Neo OTF ExtraBold
# NanumBarunGothic
# NanumBarunGothicOTF YetHangul
# NanumSquareOTF_ac
# NanumMyeongjo
# NanumSquareOTF_ac
# NanumSquare Neo ExtraBold
# Noto Sans KR
# NanumMyeongjoOTF
# NanumSquare Neo OTF Bold
# NanumSquare Neo Bold
# NanumBarunGothic
# NanumMyeongjoOTF
# NanumBarunGothicOTF
# NanumSquare Neo OTF Light
# NanumGothicOTF
# NanumSquare Neo Regular
# NanumGothicOTF
# NanumSquareRound
# NanumMyeongjo Eco
# D2Coding
# NanumGothicOTF Eco
# NanumGothic
# NanumSquareOTF
# NanumSquareRoundOTF
# NanumSquareOTF
# NanumGothic
# NanumSquareRound
# NanumSquareOTF
# NanumGothicOTF Eco
# NanumSquareRound
# Noto Sans KR
# NanumGothicOTF Eco
# NanumGothic Eco
# NanumGothicOTF
# NanumMyeongjoOTF Eco
# NanumBarunGothicOTF
# Noto Sans KR
# Nanum Pen Script OTF
# NanumSquareRoundOTF
# NanumMyeongjoOTF YetHangul
# Noto Sans KR
# Noto Sans KR
# NanumMyeongjo YetHangul
# NanumGothic Eco
# NanumMyeongjoOTF Eco
# D2Coding ligature
# NanumSquareOTF_ac
# NanumMyeongjoOTF
# NanumMyeongjo
# NanumMyeongjo
# NanumBarunGothic
# NanumSquare_ac
# D2Coding ligature
# NanumGothic
# NanumBarunGothic YetHangul
# Noto Sans KR

# %%
# Set font family globally
mpl.rcParams['font.family'] = 'Noto Sans KR'
print(mpl.rcParams['font.family'])
# Out:
# ['Noto Sans KR']

# %%
mpl.rc('axes',unicode_minus=False)

# %%
# %matplotlib inline # 그래프 안그려질떄 사용 명령어

# %% [markdown]
# ## seaborn

# %%
import seaborn as sns
sns.set_theme(style='whitegrid')

# %%
df = sns.load_dataset('titanic')
sns.countplot(x=df['class'])
#특정 column 유니크한 값들이 몇개씩 있는지
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
sns.countplot(data=df , x='class',hue='alive')
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
sns.countplot(data=df,y='deck',hue='alive') # alive에 따른 dict
# Out:
# <AxesSubplot:xlabel='count', ylabel='deck'>

# %%
tips = sns.load_dataset('tips')

# %%
sns.kdeplot(data=tips, x='total_bill')
sns.rugplot(data=tips, x='total_bill')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.scatterplot(data=tips,x='total_bill',y='tip')
sns.rugplot(data=tips , x='total_bill',y='tip',height=.1) # 값의 위치를 표현해줌
#hegiht는 그래프의 비율
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips,x='total_bill',y='tip',hue='time')
sns.rugplot(data=tips,x='total_bill',y='tip',hue='time')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
diamonds = sns.load_dataset('diamonds')
sns.scatterplot(data=diamonds, x='carat',y='price',s=5)
sns.rugplot(data=diamonds,x='carat',y='price',lw=1,alpha=.005) #lw는 투명도 , s는 점 크기
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
penguins = sns.load_dataset('penguins')
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.histplot(data=penguins,y='flipper_length_mm')
# Out:
# <AxesSubplot:xlabel='Count', ylabel='flipper_length_mm'>

# %%
sns.histplot(data=penguins,x='flipper_length_mm',bins=30)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(data=penguins,x='flipper_length_mm',kde=True)
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(data=penguins,x='flipper_length_mm',hue='species',multiple='stack')
# stack을 사용하면 누적으로 표현
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(penguins,x='flipper_length_mm',hue='species',element='step')
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(penguins,x='flipper_length_mm',hue='species',element='poly')
# poly를 넣으면 전체적인 모양을 살피는데 더 유용
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %% [markdown]
# ## 히트맵형태

# %%
sns.histplot(penguins,x='bill_depth_mm',y='body_mass_g',hue='species')
# Out:
# <AxesSubplot:xlabel='bill_depth_mm', ylabel='body_mass_g'>

# %%
sns.histplot(penguins,x='bill_depth_mm',y='species',hue='species',legend=False)
# Out:
# <AxesSubplot:xlabel='bill_depth_mm', ylabel='species'>

# %% [markdown]
# ## displot

# %%
sns.displot(data=penguins,x='flipper_length_mm')

# %%
sns.displot(data=penguins,x='flipper_length_mm',kind='kde')

# %%
sns.displot(data=penguins,x='flipper_length_mm',kind='ecdf')

# %%
sns.displot(data=penguins,x='flipper_length_mm',kde=True)

# %%
sns.displot(data=penguins,x='flipper_length_mm',y='bill_length_mm',hue='species')

# %%
sns.displot(data=penguins,x='flipper_length_mm',y='bill_length_mm',kind='kde',rug=True)
# rug는 양끝에 밀도

# %%
sns.displot(data=penguins,x='flipper_length_mm',hue='species',kind='kde')

# %%
sns.displot(data=penguins,x='flipper_length_mm',hue='species',col='sex',kind='kde',rug=True)

# %%
sns.displot(
    data=penguins,y='flipper_length_mm',hue='sex',col='species',
    kind='ecdf',height=4,aspect=.7,)
#heigth는 그림의 크기  , aspect는 좁아짐정도
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\User\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   self._figure.tight_layout(*args, **kwargs)

# %%
g = sns.displot(
    data=penguins , y='flipper_length_mm',hue='sex',
    col='species',kind='kde',height=4,aspect=.7,)
g.set_axis_labels('Density (a.u.)','Flipper length (mm)')
g.set_titles({col_name} , penguins)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [43], in <cell line: 5>()
#       1 g = sns.displot(
#       2     data=penguins , y='flipper_length_mm',hue='sex',
#       3     col='species',kind='kde',height=4,aspect=.7,)
#       4 g.set_axis_labels('Density (a.u.)','Flipper length (mm)')
# ----> 5 g.set_titles({col_name} , penguins)
#
# NameError: name 'col_name' is not defined

# %% [markdown]
# ## barplot()

# %%
df = sns.load_dataset('penguins')
sns.barplot(data=df,x='species',y='body_mass_g',hue='sex')
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %% [markdown]
# ## boxplot

# %%
df = sns.load_dataset('titanic')
sns.boxplot(x=df['age'])
# Out:
# <AxesSubplot:xlabel='age'>

# %%
sns.boxplot(data=df,x='age',y='class')
# Out:
# <AxesSubplot:xlabel='age', ylabel='class'>

# %%
sns.boxplot(data=df,x='age',y='class',hue='alive')
# Out:
# <AxesSubplot:xlabel='age', ylabel='class'>

# %%
sns.boxplot(data=df,x='fare',y='alive')
# Out:
# <AxesSubplot:xlabel='fare', ylabel='alive'>

# %%
sns.boxplot(data=df,x='fare',y='alive',order=['yes','no'])
# Out:
# <AxesSubplot:xlabel='fare', ylabel='alive'>

# %%
sns.boxplot(data=df[['age','fare']],orient='v')
# orient=v 는 수직 방향 믜미
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## violinplot()

# %%
df = sns.load_dataset('titanic')
sns.violinplot(x=df['age'])
# Out:
# <AxesSubplot:xlabel='age'>

# %%
sns.violinplot(data=df,x='age',y='class')
# Out:
# <AxesSubplot:xlabel='age', ylabel='class'>

# %%
sns.violinplot(data=df,x='class',y='age',hue='alive')
# Out:
# <AxesSubplot:xlabel='class', ylabel='age'>

# %%
sns.violinplot(data=df,x='deck',y='age',hue='alive',split=True)
# split을 사용하면 좌,우에 각각 분포(꼭 2개 분류가 되는것만 가능)
# Out:
# <AxesSubplot:xlabel='deck', ylabel='age'>

# %%
sns.violinplot(data=df,x='age',y='alive',cut=0)
# Out:
# <AxesSubplot:xlabel='age', ylabel='alive'>

# %%
sns.violinplot(data=df,x='age',y='alive',bw=.15)
# bw -> 소수 값을 갖는 비율
# Out:
# <AxesSubplot:xlabel='age', ylabel='alive'>

# %%
sns.violinplot(data=df,x='age',y='embark_town',inner='stick')
# inner키워드에 stick을 사용해 값 분포를 표시
# Out:
# <AxesSubplot:xlabel='age', ylabel='embark_town'>

# %%
sns.violinplot(data=df,x='age',y='embark_town',scale='count',cot=0)
# Out:
# <AxesSubplot:xlabel='age', ylabel='embark_town'>

# %% [markdown]
# ## stripplot()

# %%
tips = sns.load_dataset('tips')
sns.stripplot(data=tips,x='total_bill')
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.stripplot(data=tips,x='total_bill',y='day')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %%
sns.stripplot(data=tips,x='day',y='total_bill')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(data=tips,x='total_bill',y='day',hue='sex')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %%
sns.stripplot(data=tips,x='total_bill',y='day',hue='size')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %%
sns.stripplot(data=tips,x='total_bill',y='day',hue='sex',dodge=True)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %% [markdown]
# ## swarmplot()

# %%
tips = sns.load_dataset('tips')
sns.swarmplot(data=tips,x='total_bill')
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.swarmplot(data=tips,x='total_bill',y='day')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %%
sns.swarmplot(data=tips,x='day',y='total_bill')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(data=tips,x='total_bill',y='day',hue='sex')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %%
sns.swarmplot(data=tips,x='total_bill',y='day',hue='sex',dodge=True)
# dodge를 통해 범주별로 구분이 가능하다
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 9.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 6.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %%
sns.swarmplot(
    data=tips,x='total_bill',y='day',
    marker='x',linewidth=1,
)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\categorical.py:1378: UserWarning: You passed a edgecolor/edgecolors ('#4c4c4c') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   points = ax.scatter(swarm_data, cat_pos, s=s, **kws)
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %% [markdown]
# ## catplot()

# %%
df = sns.load_dataset('titanic')
sns.catplot(data=df,x='age',y='class')

# %%
sns.catplot(data=df,x='age',y='class',kind='box')

# %%
sns.catplot(
    data=df,x='age',y='class',hue='sex',
    kind='violin',bw=.25,cut=0,split=True,
)

# %%
sns.catplot(
    data=df,x='class',y='survived',col='sex',
    kind='bar',height=4,aspect=.6,
)

# %%
sns.catplot(data=df,x='age',y='class',kind='violin',color='.9',inner=None)
sns.swarmplot(data=df,x='age',y='class',size=3)
# 연속으로 그리면 겹쳐짐
# Out:
# <AxesSubplot:xlabel='age', ylabel='class'>

# %% [markdown]
# ## jointplot

# %%
penguins = sns.load_dataset('penguins')
sns.jointplot(data=penguins,x='bill_length_mm',y='bill_depth_mm',hue='species')

# %%
sns.jointplot(data=penguins,x='bill_length_mm', y='bill_depth_mm', hue='species',kind='kde')

# %%
adelie_penguins = penguins[penguins['species'] == 'Adelie']
sns.jointplot(data=adelie_penguins, x='bill_length_mm', y='bill_depth_mm',kind='reg')

# %%
sns.jointplot(data=penguins,x='bill_length_mm',y='bill_depth_mm',hue='species',
              height=7 , ratio=2 , marginal_ticks=True)

# %% [markdown]
# ## pairplot

# %%
penguins = sns.load_dataset('penguins')
sns.pairplot(penguins)

# %%
sns.pairplot(penguins,hue='species')

# %%
sns.pairplot(penguins,hue='species',diag_kind='hist')

# %%
sns.pairplot(penguins,hue='species',diag_kind='kde')

# %%
sns.pairplot(
    penguins,
    x_vars=['bill_length_mm','bill_depth_mm','flipper_length_mm'],
    y_vars=['bill_length_mm','bill_depth_mm'],
)

# %%
sns.pairplot(penguins,hue='species',corner=True)

# %% [markdown]
# ## heatmap()

# %%
import pandas as pd
ttn_cls_who = pd.pivot_table(df,'survived',index='class',columns='who')
sns.heatmap(ttn_cls_who,cmap='crest')
# Out:
# <AxesSubplot:xlabel='who', ylabel='class'>

# %%
sns.heatmap(ttn_cls_who,cmap='mako',annot=True,fmt='.2f',linewidth=.5)
# Out:
# <AxesSubplot:xlabel='who', ylabel='class'>
