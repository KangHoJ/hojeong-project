# %%
# 시스템 폰트 경로 리스트
font_list = mpl.font_manager.findSystemFonts()
print(font_list)
# 폰트 설정하기
prop = mpl.font_manager.FontProperties(fname='원하는 폰트 경로')
plt.rcParams['font.family'] = prop.get_family()
# Out:
# ['C:\\Windows\\Fonts\\comicbd.ttf', 'C:\\Windows\\Fonts\\seguihis.ttf', 'C:\\Windows\\Fonts\\javatext.ttf', 'C:\\Windows\\Fonts\\segoeuil.ttf', 'C:\\Windows\\Fonts\\LeelaUIb.ttf', 'C:\\Windows\\Fonts\\HMKMRHD.TTF', 'C:\\Windows\\Fonts\\trebucit.ttf', 'C:\\Windows\\Fonts\\HANBatangB.ttf', 'C:\\Windows\\Fonts\\trebuc.ttf', 'C:\\Windows\\Fonts\\calibriz.ttf', 'C:\\Windows\\Fonts\\taileb.ttf', 'C:\\Windows\\Fonts\\phagspab.ttf', 'C:\\Windows\\Fonts\\comici.ttf', 'C:\\Windows\\Fonts\\comic.ttf', 'C:\\Windows\\Fonts\\arial.ttf', 'C:\\Windows\\Fonts\\MalangmalangB.ttf', 'C:\\Windows\\Fonts\\webdings.ttf', 'C:\\Windows\\Fonts\\cambriaz.ttf', 'C:\\Windows\\Fonts\\GOTHIC.TTF', 'C:\\Windows\\Fonts\\seguibl.ttf', 'C:\\Windows\\Fonts\\palab.ttf', 'C:\\Windows\\Fonts\\DUBAI-BOLD.TTF', 'C:\\Windows\\Fonts\\seguisbi.ttf', 'C:\\Windows\\Fonts\\impact.ttf', 'C:\\Windows\\Fonts\\WINGDNG2.TTF', 'C:\\Windows\\Fonts\\courbi.ttf', 'C:\\Windows\\Fonts\\MTEXTRA.TTF', 'C:\\Windows\\Fonts\\HancomEQN.ttf', 'C:\
# ...

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# %pwd
# Out:
# 'C:\\Users\\User\\Desktop\\boot camp\\boot camp project\\mini project 1\\최종본\\0.Code_Data\\호정'

# %%
# %cd C:\\Users\\User\\Desktop\\boot camp
# Out:
# C:\Users\User\Desktop\boot camp

# %%
# %cd C:\\Users\\User\\Desktop\\boot camp\\boot camp project\\mini project 1\\최종본\\0.Code_Data\\호정
# Out:
# C:\Users\User\Desktop\boot camp\boot camp project\mini project 1\최종본\0.Code_Data\호정

# %%
import matplotlib as mpl
# Add every font at the specified location
font_dir = ['./fonts']
for font in mpl.font_manager.findSystemFonts(fontpaths=font_dir):
 print(mpl.font_manager.FontProperties(fname=font).get_name())
 mpl.font_manager.fontManager.addfont(font)
# Out:
# NanumGothic
# NanumSquare
# Nanum Pen Script OTF
# NanumBarunGothicOTF
# NanumSquare Neo OTF Heavy
# NanumMyeongjo YetHangul
# NanumMyeongjoOTF YetHangul
# NanumSquareOTF_ac
# NanumMyeongjo
# Noto Sans KR
# NanumBarunGothicOTF
# NanumSquare Neo OTF Light
# NanumSquareOTF
# NanumBarunpen
# NanumSquareRoundOTF
# NanumSquare Neo Heavy
# NanumGothic
# NanumGothicOTF
# NanumSquare_ac
# NanumBarunpenOTF
# NanumSquare
# NanumSquare Neo Light
# NanumMyeongjoOTF
# NanumMyeongjo Eco
# Noto Sans KR
# NanumSquare_ac
# NanumBarunGothic
# NanumGothicOTF
# NanumSquareOTF_ac
# Noto Sans KR
# NanumBarunpen
# NanumGothicOTF
# NanumGothic
# D2Coding ligature
# NanumSquareRound
# NanumBarunGothic
# NanumBarunGothicOTF
# NanumGothicOTF Eco
# NanumSquareOTF_ac
# NanumBarunGothic YetHangul
# D2Coding ligature
# NanumSquare Neo OTF ExtraBold
# NanumSquareOTF_ac
# NanumGothicOTF Eco
# NanumSquareRoundOTF
# NanumSquare Neo Regular
# NanumGothicOTF Eco
# NanumGothicOTF
# NanumGothic Eco
# NanumBarunGothicOTF
# ...

# %%
# Set font family globally
mpl.rcParams['font.family'] = 'Noto Sans KR'
print(mpl.rcParams['font.family'])
# Out:
# ['Noto Sans KR']

# %% [markdown]
# ---------------------

# %% [markdown]
# -------------

# %%
import pandas as pd
df = pd.read_csv('소상공인 서울.csv')
df.head(3)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [7], in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('소상공인 서울.csv')
#       3 df.head(3)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
df.columns
# Out:
# Index(['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드',
#        '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도코드',
#        '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명', '지번코드',
#        '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명', '건물본번지',
#        '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보',
#        '호정보', '경도', '위도'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of           상가업소번호         상호명   지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드   상권업종중분류명  \
# 0       23324279       제중건강원   NaN         D       소매       D10    건강/미용식품
# 1       24525909       민속악기사   NaN         D       소매       D04  취미/오락관련소매
# 2       24715368       태평양진주   NaN         D       소매       D26   시계/귀금속소매
# 3       15554136  김선희꼼꼼국어교습소   NaN         R    학문/교육       R01  학원-보습교습입시
# 4       17174175         비지트   NaN         Q       음식       Q01         한식
# ...          ...         ...   ...       ...      ...       ...        ...
# 377719  19079387   향나무참숯장어나라   NaN         Q       음식       Q01         한식
# 377720  19079580    에이치에스컨설팅   NaN         L      부동산       L01      부동산중개
# 377721  19079781       크린에이드  가양역점         F    생활서비스       F02   세탁/가사서비스
# 377722  19080385           멍   NaN         D       소매       D09   애견/애완/동물
# 377723  19080785       써니뷰티샵   NaN         F    생활서비스       F01    이/미용/건강
#
# ...

# %%
data = df[['상호명','지점명','상권업종대분류명','상권업종중분류명','상권업종소분류명','표준산업분류명',
          '시도명','시군구명','행정동명','법정동명','건물명','경도','위도']]

# %%
data['시군구명'].value_counts().head(10)
# Out:
# 강남구     37280
# 송파구     23171
# 서초구     22043
# 강서구     18989
# 마포구     18728
# 중구      17410
# 영등포구    16775
# 종로구     15215
# 강동구     15111
# 광진구     14564
# Name: 시군구명, dtype: int64

# %%
plt.figure(figsize = (11,4))
sns.countplot(x=data['시군구명'] , order = data['시군구명'].value_counts().index) #강남구가 가장 많음
# Out:
# <AxesSubplot:xlabel='시군구명', ylabel='count'>

# %%
area = pd.Series({'서초구' : 47,
'강서구' : 41.5,
'강남구' : 39.5,
'노원구' : 35.4,
'송파구' : 33.9,
'은평구' : 29.7,
'관악구' : 29.6,
'강동구' : 24.6,
'성북구' : 24.6,
'영등포구' : 24.5,
'종로구': 23.9,
'마포구': 23.9,
'강북구': 23.6,
'용산구': 21.9,
'도봉구': 20.7,
'구로구': 20.1,
'중랑구': 18.5,
'서대문구' : 17.6,
'양천구': 17.4,
'광진구': 17.1,
'성동구': 16.9,
'동작구': 16.4,
'동대문구' : 14.2,
'금천구' : 13,
'중구' : 10})

# %%
areas = data['시군구명'].value_counts()/area 
areas.head(3)
# Out:
# 강남구    943.797468
# 강동구    614.268293
# 강북구    406.779661
# dtype: float64

# %%
data['시군구명'].value_counts()
# Out:
# 강남구     37280
# 송파구     23171
# 서초구     22043
# 강서구     18989
# 마포구     18728
# 중구      17410
# 영등포구    16775
# 종로구     15215
# 강동구     15111
# 광진구     14564
# 구로구     14046
# 관악구     13838
# 동대문구    13474
# 은평구     13120
# 노원구     12919
# 양천구     12869
# 성북구     12751
# 중랑구     12092
# 용산구     12056
# 성동구     11623
# 금천구     10735
# 서대문구    10363
# 동작구     10357
# 강북구      9600
# 도봉구      8595
# Name: 시군구명, dtype: int64

# %%
a = areas.index
b= areas.values
plt.figure(figsize = (15,4))
sns.barplot(a,b)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
data['상권업종대분류명'].value_counts()
# Out:
# 음식          125771
# 소매          107460
# 생활서비스        79679
# 학문/교육        27288
# 부동산          19784
# 관광/여가/오락      9820
# 스포츠           5420
# 숙박            2502
# Name: 상권업종대분류명, dtype: int64

# %%
plt.figure(figsize = (30,8))
# sns.countplot(x=data['상권업종대분류명'] , order = data['상권업종대분류명'].value_counts().index) 
plt.savefig('상권업종대분류명')
exp =[0.03,0.03,0.03,0.03,0.03,0.03,0.03,0.03]
k = data['상권업종대분류명'].value_counts()
plt.pie(k,labels=k.index,explode=exp,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1c5866ba1f0>,
# ...
#  [Text(0.5661146660511577, 0.9779643065479365, '음식'),
#   Text(-1.1163282157661853, 0.17524643986194205, '소매'),
#   Text(-0.19122540013485256, -1.1137023149582053, '생활서비스'),
#   Text(0.744779955699796, -0.8498251688363967, '학문/교육'),
#   Text(1.0127033501428426, -0.5013301552963512, '부동산'),
#   Text(1.1043552975933382, -0.23937288208468774, '관광/여가/오락'),
#   Text(1.1257558128811265, -0.09784605134779192, '스포츠'),
#   Text(1.129755345768108, -0.023512947675335353, '숙박')],
#  [Text(0.31562145098427363, 0.5452367372789381, '33.3%'),
#   Text(-0.6223776778165457, 0.09770376735665794, '28.4%'),
#   Text(-0.10661239122562577, -0.6209136800209464, '21.1%'),
#   Text(0.4152313027352844, -0.4737963330680795, '7.2%'),
#   Text(0.5646045226460095, -0.2795026529528329, '5.2%'),
#   Text(0.6157025110476133, -0.1334556776224365, '2.6%'),
#   Text(0.6276337717832827, -0.05455133836204328, '1.4%'),
# ...

# %%
data[data['시군구명']=='강남구']['상권업종대분류명'].value_counts()
# Out:
# 음식          12270
# 생활서비스        8931
# 소매           8866
# 부동산          2799
# 학문/교육        2686
# 관광/여가/오락      852
# 스포츠           724
# 숙박            152
# Name: 상권업종대분류명, dtype: int64

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 10))
sns.countplot(ax=axes[0, 0],x=data[data['시군구명']=='도봉구']['상권업종대분류명'] , order = data[data['시군구명']=='도봉구']['상권업종대분류명'].value_counts().index) 
sns.countplot(ax=axes[0, 1],x=data[data['시군구명']=='동작구']['상권업종대분류명'] , order = data[data['시군구명']=='동작구']['상권업종대분류명'].value_counts().index) 
sns.countplot(ax=axes[1, 0],x=data[data['시군구명']=='중구']['상권업종대분류명'] , order = data[data['시군구명']=='중구']['상권업종대분류명'].value_counts().index) 
sns.countplot(ax=axes[1, 1],x=data[data['시군구명']=='강북구']['상권업종대분류명'] , order = data[data['시군구명']=='강북구']['상권업종대분류명'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='상권업종대분류명', ylabel='count'>

# %%
g = data.loc[(data['시군구명']=='강남구') & (data['상권업종대분류명']=='생활서비스'),]
g['상권업종중분류명'].value_counts() 
g2 = data.loc[(data['시군구명']=='강남구') & (data['상권업종대분류명']=='음식'),]
g2['상권업종중분류명'].value_counts() 
g3 = data.loc[(data['시군구명']=='강남구') & (data['상권업종대분류명']=='소매'),]
g3['상권업종중분류명'].value_counts() 
g4 = data.loc[(data['시군구명']=='강남구') & (data['상권업종대분류명']=='음식') & (data['상권업종중분류명']=='닭/오리요리'),]
g5 = g4['상권업종소분류명'].value_counts() / 39.5
                                                    


d = data.loc[(data['시군구명']=='동작구') & (data['상권업종대분류명']=='생활서비스'),]
d['상권업종중분류명'].value_counts() 
d2 = data.loc[(data['시군구명']=='동작구') & (data['상권업종대분류명']=='음식'),]
d2['상권업종중분류명'].value_counts() 
d3 = data.loc[(data['시군구명']=='동작구') & (data['상권업종대분류명']=='소매'),]
d3['상권업종중분류명'].value_counts() 
d4 = data.loc[(data['시군구명']=='동작구') & (data['상권업종대분류명']=='음식') & (data['상권업종중분류명']=='닭/오리요리'),]
d5 = d4['상권업종소분류명'].value_counts() / 16.4


v = data.loc[(data['시군구명']=='강북구') & (data['상권업종대분류명']=='생활서비스'),]
v['상권업종소분류명'].value_counts() 
v2 = data.loc[(data['시군구명']=='강북구') & (data['상권업종대분류명']=='음식'),]
v2['상권업종소분류명'].value_counts() 
v3 = data.loc[(data['시군구명']=='강북구') & (data['상권업종대분류명']=='소매'),]
v3['상권업종소분류명'].value_counts() 
v4 = data.loc[(data['시군구명']=='강북구') & (data['상권업종대분류명']=='음식') & (data['상권업종중분류명']=='닭/오리요리'),]
v5 = v4['상권업종소분류명'].value_counts() / 23.6  



m = data.loc[(data['시군구명']=='중구') & (data['상권업종대분류명']=='생활서비스'),]
m['상권업종중분류명'].value_counts() 
m2 = data.loc[(data['시군구명']=='중구') & (data['상권업종대분류명']=='음식'),]
m2['상권업종중분류명'].value_counts() 
m3 = data.loc[(data['시군구명']=='중구') & (data['상권업종대분류명']=='소매'),]
m3['상권업종중분류명'].value_counts() 
m4 = data.loc[(data['시군구명']=='중구') & (data['상권업종대분류명']=='음식') & (data['상권업종중분류명']=='닭/오리요리'),]
m5 = m4['상권업종소분류명'].value_counts() / 10


s = data.loc[(data['시군구명']=='중구') & (data['상권업종대분류명']=='생활서비스'),]
s['상권업종중분류명'].value_counts() 
s2 = data.loc[(data['시군구명']=='중구') & (data['상권업종대분류명']=='음식'),]
s2['상권업종중분류명'].value_counts() 
s3 = data.loc[(data['시군구명']=='중구') & (data['상권업종대분류명']=='소매'),]
s3['상권업종중분류명'].value_counts() 
s4 = data.loc[(data['시군구명']=='중구') & (data['상권업종대분류명']=='음식') & (data['상권업종중분류명']=='닭/오리요리'),]
s5 = m4['상권업종소분류명'].value_counts() / 16.9

# %% [markdown]
# - 강남구 분석

# %%
# 강남구 생활서비스 분석
plt.figure(figsize = (30,4)) 
sns.countplot(x=g['상권업종중분류명'] , order = g['상권업종중분류명'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='상권업종중분류명', ylabel='count'>

# %%
# 강남구 음식 분석
plt.figure(figsize = (30,4)) # 강남구
sns.countplot(x=g2['상권업종중분류명'] , order = g2['상권업종중분류명'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='상권업종중분류명', ylabel='count'>

# %%
# 강남구 소매 분석
plt.figure(figsize = (30,4)) # 강남구
sns.countplot(x=g3['상권업종중분류명'] , order = g3['상권업종중분류명'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='상권업종중분류명', ylabel='count'>

# %% [markdown]
# - 동작구 분석

# %%
# 생활 서비스 분석 
plt.figure(figsize = (30,4)) 
sns.countplot(x=d['상권업종중분류명'] , order = d['상권업종중분류명'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='상권업종중분류명', ylabel='count'>

# %%
# 음식 분석 
plt.figure(figsize = (30,4)) 
sns.countplot(x=d2['상권업종중분류명'] , order = d2['상권업종중분류명'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='상권업종중분류명', ylabel='count'>

# %%
# 소매 분석
plt.figure(figsize = (30,4)) 
sns.countplot(x=d3['상권업종중분류명'] , order = d3['상권업종중분류명'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='상권업종중분류명', ylabel='count'>

# %% [markdown]
# - 강북구 분석

# %%
# 강북구 생활서비스 분석
plt.figure(figsize = (30,4)) 
sns.countplot(x=v['상권업종중분류명'] , order = v['상권업종중분류명'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='상권업종중분류명', ylabel='count'>

# %%
# 강북구 음식
plt.figure(figsize = (30,4)) 
sns.countplot(x=v2['상권업종중분류명'] , order = v2['상권업종중분류명'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='상권업종중분류명', ylabel='count'>

# %%
# 강남구 소매 분석
plt.figure(figsize = (30,4)) 
sns.countplot(x=v3['상권업종중분류명'] , order = v3['상권업종중분류명'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='상권업종중분류명', ylabel='count'>

# %% [markdown]
# - 중구 분석

# %%
# 중구 생활서비스 분석
plt.figure(figsize = (30,4)) 
sns.countplot(x=m['상권업종중분류명'] , order = m['상권업종중분류명'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='상권업종중분류명', ylabel='count'>

# %%
# 중구 음식
plt.figure(figsize = (30,4)) 
sns.countplot(x=m2['상권업종중분류명'] , order = m2['상권업종중분류명'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='상권업종중분류명', ylabel='count'>

# %%
# 중구 소매 분석
plt.figure(figsize = (30,4)) 
sns.countplot(x=m3['상권업종중분류명'] , order = m3['상권업종중분류명'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='상권업종중분류명', ylabel='count'>

# %% [markdown]
# - 성동구 분석

# %%
# 중구 생활서비스 분석
plt.figure(figsize = (30,4)) 
sns.countplot(x=s['상권업종중분류명'] , order = s['상권업종중분류명'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='상권업종중분류명', ylabel='count'>

# %%
# 중구 음식
plt.figure(figsize = (30,4)) 
sns.countplot(x=s2['상권업종중분류명'] , order = s2['상권업종중분류명'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='상권업종중분류명', ylabel='count'>

# %%
# 중구 소매 분석
plt.figure(figsize = (30,4)) 
sns.countplot(x=s3['상권업종중분류명'] , order = s3['상권업종중분류명'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='상권업종중분류명', ylabel='count'>

# %% [markdown]
# - 닭요리 분석(면적대비)

# %%
# 강남구 닭요리 분석 
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(28, 10))

a = g5.index
b= g5.values
sns.barplot(a, b , ax=axes[0, 0]) 

aa = d5.index
bb= d5.values
sns.barplot(aa, bb , ax=axes[0, 1])

aaa = v5.index
bbb= v5.values
sns.barplot(aaa, bbb , ax=axes[1, 0])

aaaa = m5.index
bbbb= m5.values
sns.barplot(aaaa,bbbb , ax=axes[1, 1])
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [70], in <cell line: 7>()
#       5 b= g5.values
#       6 sns.barplot(a, b , ax=axes[0, 0])
# ----> 7 plt.xlabel('nonvolatile acid', fontsize=15,ax=[0,0])
#       9 aa = d5.index
#      10 bb= d5.values
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:3033, in xlabel(xlabel, fontdict, labelpad, loc, **kwargs)
#    3031 @_copy_docstring_and_deprecators(Axes.set_xlabel)
#    3032 def xlabel(xlabel, fontdict=None, labelpad=None, *, loc=None, **kwargs):
# ...
