# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
#!sudo apt-get install -y fonts-nanum
#!sudo fc-cache -fv
#!rm ~/.cache/matplotlib -rf

# %%
plt.rc('font', family='NanumBarunGothic')

# %%
rank = pd.read_csv('/content/drive/MyDrive/Miniproject_No_1/0.Code&Data/datas/행정동별랭킹.csv')
rank.columns
# Out:
# Index(['행정동', '주간 생활인구 수', '주간순위', '야간 생활인구 수', '야간 순위', '학교 수', '학교 순위',
#        '버스 정류장수', '버스 정류장수 순위', '지하철수', '지하철수 순위', '치킨집 수', '치킨집 순위', '공원 수',
#        '공원 순위'],
#       dtype='object')

# %%
rank
# Out:
#         행정동  주간 생활인구 수  주간순위  야간 생활인구 수  야간 순위  학교 수  학교 순위  버스 정류장수  \
# 0    성수2가3동      45807     1      25753     15     5      3       56
# 1    왕십리도선동      29457     2      30807     17     2     10       11
# 2       옥수동      26340     3      28162     16     4      7       50
# 3       사근동      24598     4      20860     12     4      7       21
# 4    성수1가2동      23749     5      17152      7     6      1       46
# 5      행당1동      22206     6      19670     10     5      3       77
# 6    성수1가1동      21891     7      16799      6     6      1       46
# 7    성수2가1동      21668     8      18626      8     5      3       56
# 8       마장동      21362     9      21026     13     4      7       32
# 9       용답동      20589    10      19021      9     1     15        7
# 10  금호2,3가동      18595    11      23030     14     1     15       41
# 11     행당2동      16397    12      20368     11     5      3       77
# 12    금호1가동      13998    13      15698      4     2     10       44
# ...

# %%
# 주간
jugan = rank[['행정동','주간순위']].set_index('행정동').sort_index()['주간순위']
jugan
# Out:
# 행정동
# 금호1가동      13
# 금호2,3가동    11
# 금호4가동      15
# 마장동         9
# 사근동         4
# 성수1가1동      7
# 성수1가2동      5
# 성수2가1동      8
# 성수2가3동      1
# 송정동        16
# 옥수동         3
# 왕십리2동      14
# 왕십리도선동      2
# 용답동        10
# 응봉동        17
# 행당1동        6
# 행당2동       12
# Name: 주간순위, dtype: int64

# %%
# 야간
yagan = rank[['행정동','야간 순위']].set_index('행정동').sort_index()['야간 순위']
yagan
# Out:
# 행정동
# 금호1가동       4
# 금호2,3가동    14
# 금호4가동       2
# 마장동        13
# 사근동        12
# 성수1가1동      6
# 성수1가2동      7
# 성수2가1동      8
# 성수2가3동     15
# 송정동         1
# 옥수동        16
# 왕십리2동       5
# 왕십리도선동     17
# 용답동         9
# 응봉동         3
# 행당1동       10
# 행당2동       11
# Name: 야간 순위, dtype: int64

# %%
# 학교 순위
school = rank[['행정동','학교 순위']].set_index('행정동').sort_index()['학교 순위']
school
# Out:
# 행정동
# 금호1가동      10
# 금호2,3가동    15
# 금호4가동      10
# 마장동         7
# 사근동         7
# 성수1가1동      1
# 성수1가2동      1
# 성수2가1동      3
# 성수2가3동      3
# 송정동        15
# 옥수동         7
# 왕십리2동      10
# 왕십리도선동     10
# 용답동        15
# 응봉동        10
# 행당1동        3
# 행당2동        3
# Name: 학교 순위, dtype: int64

# %%
# 버스 정류장수 순위
bus = rank[['행정동','버스 정류장수 순위']].set_index('행정동').sort_index()['버스 정류장수 순위']
bus
# Out:
# 행정동
# 금호1가동       8
# 금호2,3가동     9
# 금호4가동      10
# 마장동        12
# 사근동        14
# 성수1가1동      6
# 성수1가2동      6
# 성수2가1동      3
# 성수2가3동      3
# 송정동        15
# 옥수동         5
# 왕십리2동      13
# 왕십리도선동     16
# 용답동        17
# 응봉동        11
# 행당1동        1
# 행당2동        1
# Name: 버스 정류장수 순위, dtype: int64

# %%
# 지하철 순위
subway = rank[['행정동','지하철수 순위']].set_index('행정동').sort_index()['지하철수 순위']
subway
# Out:
# 행정동
# 금호1가동      12
# 금호2,3가동    12
# 금호4가동       5
# 마장동        12
# 사근동        12
# 성수1가1동      5
# 성수1가2동      5
# 성수2가1동      5
# 성수2가3동      5
# 송정동        12
# 옥수동         4
# 왕십리2동       5
# 왕십리도선동      5
# 용답동         3
# 응봉동        12
# 행당1동        1
# 행당2동        1
# Name: 지하철수 순위, dtype: int64

# %%
# 치킨집 순위
chicken = rank[['행정동','치킨집 순위']].set_index('행정동').sort_index()['치킨집 순위']
chicken
# Out:
# 행정동
# 금호1가동       5
# 금호2,3가동    13
# 금호4가동      11
# 마장동         5
# 사근동        11
# 성수1가1동      2
# 성수1가2동      8
# 성수2가1동      8
# 성수2가3동     15
# 송정동         1
# 옥수동         5
# 왕십리2동      13
# 왕십리도선동     17
# 용답동         8
# 응봉동         2
# 행당1동       16
# 행당2동        4
# Name: 치킨집 순위, dtype: int64

# %%
rank2_df.set_index('행정동',inplace=True)

# %%
rank3_df = pd.concat([rank2_df, rank2], axis=1)
rank3_df
# Out:
#          주간 생활인구  야간 생활인구  경쟁 치킨업체 수  공원 수  학교 수  버스 정류장 수  지하철 역 수   0
# 행정동
# 금호1가동         13        4          5    15    10         8       12  67
# 금호2,3가동       11       14         13     6    15         9       12  80
# 금호4가동         15        2         11    11    10        10        5  64
# 마장동            9       13          5     6     7        12       12  64
# 사근동            4       12         11    15     7        14       12  75
# 성수1가1동         7        6          2     6     1         6        5  33
# 성수1가2동         5        7          8     6     1         6        5  38
# 성수2가1동         8        8          8     1     3         3        5  36
# 성수2가3동         1       15         15     1     3         3        5  43
# 송정동           16        1          1    11    15        15       12  71
# 옥수동            3       16          5    11     7         5        4  51
# 왕십리2동         14        5         13     1    10        13        5  61
# ...

# %%
rank3_df.rename(columns={0:'순위 합 결과'},inplace=True)
rank3_df
# Out:
#          주간 생활인구  야간 생활인구  경쟁 치킨업체 수  공원 수  학교 수  버스 정류장 수  지하철 역 수  순위 합 결과
# 행정동
# 금호1가동         13        4          5    15    10         8       12       67
# 금호2,3가동       11       14         13     6    15         9       12       80
# 금호4가동         15        2         11    11    10        10        5       64
# 마장동            9       13          5     6     7        12       12       64
# 사근동            4       12         11    15     7        14       12       75
# 성수1가1동         7        6          2     6     1         6        5       33
# 성수1가2동         5        7          8     6     1         6        5       38
# 성수2가1동         8        8          8     1     3         3        5       36
# 성수2가3동         1       15         15     1     3         3        5       43
# 송정동           16        1          1    11    15        15       12       71
# 옥수동            3       16          5    11     7         5        4       51
# ...

# %%
rank3_df = rank3_df.sort_values(by='순위 합 결과',ascending=True)
rank3_df
# Out:
#          주간 생활인구  야간 생활인구  경쟁 치킨업체 수  공원 수  학교 수  버스 정류장 수  지하철 역 수  순위 합 결과
# 행정동
# 성수1가1동         7        6          2     6     1         6        5       33
# 행당2동          12       11          4     4     3         1        1       36
# 성수2가1동         8        8          8     1     3         3        5       36
# 성수1가2동         5        7          8     6     1         6        5       38
# 행당1동           6       10         16     4     3         1        1       41
# 성수2가3동         1       15         15     1     3         3        5       43
# 옥수동            3       16          5    11     7         5        4       51
# 왕십리2동         14        5         13     1    10        13        5       61
# 마장동            9       13          5     6     7        12       12       64
# 금호4가동         15        2         11    11    10        10        5       64
# 응봉동           17        3          2    10    10        11       12       65
# ...

# %%
rank3_df

# %%
rank2 = jugan + yagan + school + bus + subway + chicken + park
rank2
# Out:
# 행정동
# 금호1가동      67
# 금호2,3가동    80
# 금호4가동      64
# 마장동        64
# 사근동        75
# 성수1가1동     33
# 성수1가2동     38
# 성수2가1동     36
# 성수2가3동     43
# 송정동        71
# 옥수동        51
# 왕십리2동      61
# 왕십리도선동     78
# 용답동        77
# 응봉동        65
# 행당1동       41
# 행당2동       36
# dtype: int64

# %%
rank2.sort_values(ascending=True)
# Out:
# 행정동
# 성수1가1동     33
# 행당2동       36
# 성수2가1동     36
# 성수1가2동     38
# 행당1동       41
# 성수2가3동     43
# 옥수동        51
# 왕십리2동      61
# 마장동        64
# 금호4가동      64
# 응봉동        65
# 금호1가동      67
# 송정동        71
# 사근동        75
# 용답동        77
# 왕십리도선동     78
# 금호2,3가동    80
# dtype: int64

# %%
import seaborn as sns

# %%
rank2 = rank2.sort_values(ascending=True)

# %%
plt.figure(figsize=(12,12))
plt.title('행정동 수요자 중심 상권 선정')
ax = sns.barplot(y=rank2.index, x=rank2.values, dodge=False, palette='Spectral')
ax.tick_params(axis='y',labelsize=14)
for p in ax.patches:
    x, y, width, height = p.get_bbox().bounds
    ax.text(width*1.01, y+height/2, "%.0f"%(width), va='center')
plt.show()
